# %%
# !pip install transformer_lens

# %%
# !rm -rf ai-safety-project-2025/
# !git clone --branch clean-notebook https://github.com/FranciscoHS/ai-safety-project-2025
# %cd /content/ai-safety-project-2025
# !git pull

import sys
sys.path.append('/content/ai-safety-project-2025/src/')

# %%
# !python scripts/run.py --N 10 --steps 5000 --seed 1

# %%
# !python scripts/detect_grokking.py --N 10 --frac_train 0.72 --d_model 128 --n_heads 4 --d_mlp 512 --seed 1

# %%
from google.colab import drive; drive.mount('/content/drive')
# !mkdir -p /content/drive/MyDrive/aises_project/figures/curves
# %cd /content/ai-safety-project-2025
# !python scripts/plot_loss.py --N 10 --frac_train 0.72 --d_model 128 --n_heads 4 --d_mlp 512 --seed 1 --smooth 11 --logy \
  --out /content/drive/MyDrive/aises_project/figures/curves

# %%
from google.colab import drive; drive.mount('/content/drive')
# !python scripts/pca_and_ablate.py --N 10 --seed 0 --csv /content/drive/MyDrive/aises_project/experiments.csv
